# %% [markdown]
# #  Deep Learning and Image Recognition
#
# ## Decision Tree Regression with AdaBoost
#
# A decision tree is boosted using the AdaBoost.R2 algorithm on a 1D sinusoidal dataset with a small amount of Gaussian noise. 299 boosts (300 decision trees) is compared with a single decision tree regressor. As the number of boosts is increased the regressor can fit more detail.

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
# Create the dataset
rng = np.random.RandomState(1)
X = np.linspace(0, 6, 100)[:, np.newaxis]
y = np.sin(X).ravel() + np.sin(6 * X).ravel() + rng.normal(0, 0.1, X.shape[0])

# %%
# Plot the results
plt.figure(figsize=(12,6))
plt.scatter(X, y, c="k", label="training samples")
plt.xlabel("data", size=14)
plt.ylabel("target", size=14)
plt.title("Sinusoidal + Gaussian noise", size=16)
plt.legend()
plt.show()

# %%
# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=4)

regr_2 = AdaBoostRegressor(DecisionTreeRegressor(max_depth=6),
                          n_estimators=20, random_state=rng)

regr_3 = AdaBoostRegressor(DecisionTreeRegressor(max_depth=6),
                          n_estimators=100, random_state=rng)

regr_1.fit(X, y)
regr_2.fit(X, y)
regr_3.fit(X, y)

# Predict
y_1 = regr_1.predict(X)
y_2 = regr_2.predict(X)
y_3 = regr_3.predict(X)

# %%
# Plot the results
plt.figure(figsize=(12,6))
plt.scatter(X, y, c="k", label="training samples")
plt.plot(X, y_1, c="b", label="n_estimators=1", linewidth=2)
plt.plot(X, y_2, c="g", label="n_estimators=20", linewidth=2)
plt.xlabel("data", size=14)
plt.ylabel("target", size=14)
plt.title("Boosted Decision Tree Regression", size=16)
plt.legend()
plt.show()

# %%
# Plot the results
plt.figure(figsize=(12,6))
plt.scatter(X, y, c="k", label="training samples")
plt.plot(X, y_1, c="b", label="n_estimators=1", linewidth=2)
plt.plot(X, y_3, c="r", label="n_estimators=100", linewidth=2)
plt.xlabel("data", size=14)
plt.ylabel("target", size=14)
plt.title("Boosted Decision Tree Regression", size=16)
plt.legend()
plt.show()
